# %% [markdown]
# ## FD 1 layer data generator part 1

# %%
! pip install numpy pmcx jdata bjdata matplotlib
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pmcx in /usr/local/lib/python3.12/dist-packages (0.6.2)
# Requirement already satisfied: jdata in /usr/local/lib/python3.12/dist-packages (0.8.3)
# Requirement already satisfied: bjdata in /usr/local/lib/python3.12/dist-packages (0.5.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pickle
import math
import io
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Path to your folder containing the .py script
folder_path = '/content/drive/MyDrive/Colab Notebooks/AI_MetaOx/Stage2/'
sys.path.append(folder_path)

# Verify the file exists before importing
import os
file_path = os.path.join(folder_path, 'FD_msNIRS_onelayer.py')
from FD_msNIRS_onelayer import mcx_sim_onelayer as ms1

# %% [markdown]
# ### Read CSV and coef

# %%
# csv file to simulate: change the path!.
csv_path = '/content/drive/MyDrive/Colab Notebooks/AI_MetaOx/Stage2/Simulation_GT/stage2_part_1.csv'
df = pd.read_csv(csv_path)
# simulations save path
save_path = '/content/drive/MyDrive/Colab Notebooks/AI_MetaOx/Stage2/Simulation_Result/part_1/'

# %%
# lambdas = [690, 750, 805, 808, 830] #690, 750, 808, 830
coef_path = '/content/drive/MyDrive/Colab Notebooks/AI_MetaOx/EC.xlsx'
extinction_coeffs = pd.read_excel(coef_path)

# %%
# part_str = csv_path.split('/')[-1].replace('.csv', '').split('_')[-2] + '_' + csv_path.split('_')[-1].replace('.csv', '')
# print(part_str)
# # make in to be .1
# df['d1'] = df['d1'].round(0)

# %%
df.head()
# Out:
#         HBO        HHB        CCO         a         b  ID
# 0  42.37643  24.714467  17.558357  4.158487  1.565626   1
# 1  84.87643   7.214467   8.558357  2.608487  3.065626   2
# 2  21.12643  33.464467  13.058357  1.833487  0.815626   3
# 3  63.62643  15.964467   4.058357  3.383487  2.315626   4
# 4  74.25143  37.839467  10.808357  1.445987  1.190626   5

# %% [markdown]
# ### Generate data using package

# %%
import os

# List all .pkl files in the folder
existing_files = [f for f in os.listdir(save_path) if f.endswith('.pkl')]

# Extract numeric IDs from filenames like "123.pkl"
existing_ids = [int(f.replace('.pkl', '')) for f in existing_files if f.replace('.pkl', '').isdigit()]

if existing_ids:
    next_id = max(existing_ids) + 1
else:
    next_id = min_id = df['ID'].min()

print(f'Next ID to run: {next_id}')
# Out:
# Next ID to run: 1

# %%
import pickle

# %%
min_id = df['ID'].min()
max_id = df['ID'].max()

for i in range (next_id, max_id+1):
# for i in range (9006,9007):
  first_row = df[df['ID'] == i].iloc[0]
  HBO=first_row['HBO']
  HHB=first_row['HHB']
  CCO=first_row['CCO']
  a=first_row['a']
  b=first_row['b']
  id=first_row['ID']
  data = ms1(hbo=HBO, hhb=HHB, cco=CCO, coef_path = extinction_coeffs, a=a, b=b, tend=2e-09, devf=1000, nphoton=1.2e8)
  with open(f'{save_path}{int(id)}.pkl', 'wb') as f:
    pickle.dump(data, f)
    print(f'{save_path}{int(id)}.pkl', ' saved')
# Out:
# nphoton: 1.2e+08
# tstart: 0
# tstep: 2e-12
# tend: 2e-09
# maxdetphoton: 1.2e+08
# issrcfrom0: 1
# autopilot: 1
# unitinmm: 1
# issaveref: 1
# issavedet: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3493219286.py in <cell line: 0>()
#      11   b=first_row['b']
#      12   id=first_row['ID']
# ---> 13   data = ms1(hbo=HBO, hhb=HHB, cco=CCO, coef_path = extinction_coeffs, a=a, b=b, tend=2e-09, devf=1000, nphoton=1.2e8)
#      14   with open(f'{save_path}{int(id)}.pkl', 'wb') as f:
#      15     pickle.dump(data, f)
#
# /content/drive/MyDrive/Colab Notebooks/AI_MetaOx/Stage2/FD_msNIRS_onelayer.py in mcx_sim_onelayer(hbo, hhb, cco, coef_path, a, b, lambdas, g, n, distance, tend, devf, nphoton, source_type)
#     153     TPSF_list = []  # one entry per wavelength
#     154     for sim_idx, (ua, us) in enumerate(zip(mu_a, mu_s)):
# --> 155         tpsr,tpsf = mcx_simulation(ua, us, g, n, distance, tend, devf, nphoton, source_type)
#     156         TPSF_list.append({
#     157             "sim_idx": sim_idx,
#
# /content/drive/MyDrive/Colab Notebooks/AI_MetaOx/Stage2/FD_msNIRS_onelayer.py in mcx_simulation(ua, us, g, n, distance, tend, devf, nphoton, source_type)
#     129
#     130 def mcx_simulation(ua, us, g = g_default, n = n_default, distance = distance_default, tend =2e-09, devf = 10000, nphoton = 1e8, source_type = 'laser'):
# --> 131     res, cfg = run_mcx(ua, us, g, n, distance, tend, devf, nphoton, source_type)
#     132     reflectence_list = res['dref'][49, 49:99, 0, :]
#     133     Fluence_list = res['flux'][49, 49:99, 1, :]
#
# /content/drive/MyDrive/Colab Notebooks/AI_MetaOx/Stage2/FD_msNIRS_onelayer.py in run_mcx(ua, us, g, n, distances, tend, devf, nphoton, source_type)
#      89
#      90     # Run the simulation
# ---> 91     res = pmcx.mcxlab(cfg)
#      92     return res, cfg
#      93
#
# /usr/local/lib/python3.12/dist-packages/pmcx/utils.py in mcxlab(*args)
#     619                 args[0]["savedetflag"][detfields == 0] = []
#     620
# --> 621     varargout = run(args[0])
#     622
#     623     if len(args) == 0:
#
# KeyboardInterrupt:
